# %%
import pandas as pd
file_path=  './mchnt/liaoning_canyin_2.DEL'
#print(file_path)
fr = open(file_path,"r",encoding='utf-8')
data = [line.strip().split('\t') for line in fr]
feature = [ row[1:117] for row in data]
column_nm=['mchnt_cd',"trans_cnt","succ_trans_cnt","succ_trans_at","settle_cnt","neg_settle_cnt","settle_at","consume_cnt","neg_consume_cnt","consume_at","succ_settle_cnt","succ_settle_at","common_ds_cnt","common_ds_at","max_succ_trans_at","credit_card_cnt","neg_credit_card_cnt","debit_card_cnt","neg_debit_card_cnt","credit_card_at","debit_card_at","credit_fail_cnt","credit_fail_overdrawn_cnt","credit_fail_pin_cnt","credit_fail_insufficient_cnt","credit_fail_expiration_cnt","credit_fail_id_mismatch_cnt","debit_fail_cnt","debit_fail_overdrawn_cnt","debit_fail_pin_cnt","debit_fail_insufficient_cnt","debit_fail_expiration_cnt","debit_fail_id_mismatch_cnt","cross_consume_cnt","cross_consume_at","retrieval_cnt","retrieval_at","revoke_cnt","revoke_at","tr_return_cnt","tr_return_at","total_disc_at","ext_cups_disc_at","ext_iss_disc_at","acq_disc_at","brand_disc_at","mchnt_disc_at","iss_swt_disc_at","acq_swt_disc_at","iss_brand_disc_at","acq_brand_disc_at","iss_exch_disc_at","acq_exch_disc_at","cross_disc_at","hce_prod_cnt","hce_prod_at","am_prod_cnt","am_prod_at","paymst_prod_cnt","paymst_prod_at","payic_prod_cnt","payic_prod_at","bigmchnt_prod_cnt","bigmchnt_prod_at","huawei_prod_cnt","huawei_prod_at","mi_prod_cnt","mi_prod_at","other_qp_prod_cnt","other_qp_prod_at","nopwd_petty_cnt","nopwd_petty_at","web_cnt","web_at","mobile_cnt","mobile_at","atm_cnt","atm_at","pos_cnt","pos_at","tel_cnt","tel_at","peasant_cnt","peasant_at","other_chnl_at","other_chnl_cnt","at_ls_1_cnt","at_1_5_cnt","at_5_10_cnt","at_10_50_cnt","at_50_100_cnt","at_100_300_cnt","at_300_500_cnt","at_500_1000_cnt","at_1000_2000_cnt","at_2000_3714_cnt","at_3714_5000_cnt","at_5000_10000_cnt","at_10000_50000_cnt","at_gt_50000_cnt","at_ls_1_at","at_1_5_at","at_5_10_at","at_10_50_at","at_50_100_at","at_100_300_at","at_300_500_at","at_500_1000_at","at_1000_2000_at","at_2000_3714_at","at_3714_5000_at","at_5000_10000_at","at_10000_50000_at","at_gt_50000_at","term_num","is_white_list_mchnt"]
df = pd.DataFrame(feature,columns=column_nm)
df.head()
# Out:
#           mchnt_cd trans_cnt succ_trans_cnt succ_trans_at settle_cnt  \
# 0  103210758126025        15             14        552200         13
# 1  104211158120061        45             41       2319200         25
# 2  105210158120919        13             11       1478600          8
# 3  105221000027517         2              2             0          2
# 4  105221000033141         2              2             0          2
#
#   neg_settle_cnt settle_at consume_cnt neg_consume_cnt consume_at  \
# 0              0    552200          13               0     552200
# 1              1   1219200          25               1    1219200
# 2              1   1478600           8               1    1478600
# 3              1         0           2               1          0
# 4              1         0           2               1          0
#
#           ...         at_300_500_at at_500_1000_at at_1000_2000_at  \
# 0         ...                110500         111900          194800
# 1         ...                339500         248800          101100
# 2         ...                     0              0          141900
# 3         ...                     0              0               0
# 4         ...                     0              0               0
#
#   at_2000_3714_at at_3714_5000_at at_5000_10000_at at_10000_50000_at  \
# 0               0               0                0                 0
# 1          361000               0                0                 0
# 2          836700               0           500000                 0
# 3               0               0                0                 0
# 4               0               0                0                 0
#
#   at_gt_50000_at term_num is_white_list_mchnt
# 0              0        1                   0
# 1              0        1                   0
# 2              0        1                   0
# 3              0        1                   0
# 4              0        1                   0
#
# [5 rows x 116 columns]

# %%
df['mean_cnt'] = df['succ_trans_at'].astype(float)/df['succ_trans_cnt'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5bafc20efaa6> in <module>()
# ----> 1 df['mean_cnt'] = df['succ_trans_at'].astype(float)/df['succ_trans_cnt'].astype(float)
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
feature_v1 = ['succ_trans_cnt','succ_trans_at','max_succ_trans_at','total_disc_at','mean_cnt']
#feature_v3 = ['succ_trans_cnt','succ_trans_at','max_succ_trans_at','credit_card_cnt','credit_card_at','total_disc_at','ext_cups_disc_at']
feature_v2 = ['settle_cnt','settle_at','mchnt_cd','at_ls_1_cnt','at_1_5_cnt','at_5_10_cnt','at_10_50_cnt',
              'at_50_100_cnt','at_100_300_cnt','at_300_500_cnt','at_500_1000_cnt','at_1000_2000_cnt',
              'at_2000_3714_cnt','at_3714_5000_cnt','at_5000_10000_cnt','at_10000_50000_cnt','at_gt_50000_cnt','at_ls_1_at','at_1_5_at',
              'at_5_10_at','at_10_50_at','at_50_100_at','at_100_300_at','at_300_500_at','at_500_1000_at','at_1000_2000_at','at_2000_3714_at',
              'at_3714_5000_at','at_5000_10000_at','at_10000_50000_at','at_gt_50000_at']

# %%
#feature_v3 = ['mchnt_cd','succ_trans_cnt','succ_trans_at']
dd = df[feature_v2]
dd['mean_at'] = dd['settle_at'].astype(float)/dd['settle_cnt'].astype(float)
dd['low_cnt'] = dd['at_ls_1_cnt'].astype(float)+dd['at_1_5_cnt'].astype(float)+dd['at_5_10_cnt'].astype(float)+dd['at_10_50_cnt'].astype(float)+dd['at_50_100_cnt'].astype(float)
dd['low_at'] = dd['at_ls_1_at'].astype(float)+dd['at_1_5_at'].astype(float)+dd['at_5_10_at'].astype(float)+dd['at_10_50_at'].astype(float)+dd['at_50_100_at'].astype(float)
dd['mid_cnt'] = dd['at_2000_3714_cnt'].astype(float)+dd['at_100_300_cnt'].astype(float)+dd['at_300_500_cnt'].astype(float)+dd['at_500_1000_cnt'].astype(float)+dd['at_1000_2000_cnt'].astype(float)
dd['mid_at'] = dd['at_2000_3714_at'].astype(float)+dd['at_100_300_at'].astype(float)+dd['at_300_500_at'].astype(float)+dd['at_500_1000_at'].astype(float)+dd['at_1000_2000_at'].astype(float)
dd['high_at'] = dd['at_3714_5000_at'].astype(float)+dd['at_5000_10000_at'].astype(float)+dd['at_10000_50000_at'].astype(float)+dd['at_gt_50000_at'].astype(float)
dd['high_cnt'] = dd['at_3714_5000_cnt'].astype(float)+dd['at_5000_10000_cnt'].astype(float)+dd['at_10000_50000_cnt'].astype(float)+dd['at_gt_50000_cnt'].astype(float)
dd
# Out:
# E:\Anaconda\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# E:\Anaconda\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# E:\Anaconda\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# E:\Anaconda\lib\site-packages\ipykernel\__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# E:\Anaconda\lib\site-packages\ipykernel\__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# E:\Anaconda\lib\site-packages\ipykernel\__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# E:\Anaconda\lib\site-packages\ipykernel\__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#       settle_cnt  settle_at         mchnt_cd at_ls_1_cnt at_1_5_cnt  \
# 0             13     552200  103210758126025           0          0
# 1             25    1219200  104211158120061           0          0
# 2              8    1478600  105210158120919           2          0
# 3              2          0  105221000027517           0          2
# 4              2          0  105221000033141           0          2
# 5              1      33000  105226000000935           0          0
# 6              2      20400  105228000000874           0          0
# 7              1    1850000  105228100000444           0          0
# 8              3     108000  105231000000995           0          0
# 9              1      82500  105234000001089           0          0
# 10             1     400000  105234400000664           0          0
# 11            13     859800  105236000001476           0          0
# 12             4     151000  113210158120037           0          0
# 13             8    2032500  113210758120017           2          0
# 14             2     150888  113210958120026           0          0
# 15            31     119210  301210158140034           0          0
# 16           132    4065300  301210758120126           0          0
# 17           216    9209000  301999358120070           0          0
# 18           100    5547809  301999458121191           0          1
# 19            58    8062149  801221058120018           0          0
# 20            25    1619700  801221058120351           0          0
# 21            43    4909100  801221058120469           0          0
# 22            17     261000  801221058120964           0          0
# 23             8     243700  80122105812101A           0          0
# 24             1      27500  801221058121242           0          0
# 25             3    1513000  80122105812369E           0          0
# 26             1      15500  80122105812597B           0          0
# 27             1     200000  80122105812641B           0          0
# 28             2    3558000  80122105812730C           0          0
# 29             3      93900  80122105812775D           0          0
# ...          ...        ...              ...         ...        ...
# 44327          2     151000  88722D158129470           0          0
# 44328          1     115000  88722D158129632           0          0
# 44329         22   10047501  88722D158131477           1          0
# 44330          2     426300  88722D158132863           0          0
# 44331          3     399800  88722D158133754           0          0
# 44332          1          1  88722D158134645           1          0
# 44333          3     255200  88722D258120113           0          0
# 44334          5    1295700  88722D258123237           0          0
# 44335          4     901000  88722FB58121820           0          0
# 44336         49    7556500  88723D058120529           0          0
# 44337        202  147173450  88723D058120862           0          0
# 44338          1     998000  88723D058121591           0          0
# 44339          5     532400  890221658121063           0          0
# 44340          6     992657  890221658125573           0          0
# 44341          4     632800  890221858135996           0          0
# 44342          3      48500  890231358144019           0          0
# 44343          1      27900  890235158130476           0          0
# 44344          7    2368902  898210158129046           2          0
# 44345         17     632601  898210358140016           3          0
# 44346          2     129500  898210758122456           0          0
# 44347        109    5816700  898210758122618           0          0
# 44348          4      16000  898211158121058           0          0
# 44349         43    1763101  898211358120220           1          0
# 44350          9     352100  898211358120338           0          0
# 44351         40    1281600  898211458120117           0          0
# 44352          3      91500  954227358110005           0          0
# 44353         50    1452900  990221058146030           0          0
# 44354          1          1  QRC010522101130           1          0
# 44355        129      66259  QRC490022005170           1         73
# 44356         29      27867  QRC490022005288           0          1
#
#       at_5_10_cnt at_10_50_cnt at_50_100_cnt at_100_300_cnt at_300_500_cnt  \
# 0               0            0             0              7              3
# 1               0            0             1              6             10
# 2               0            0             0              0              0
# 3               0            0             0              0              0
# 4               0            0             0              0              0
# 5               0            0             0              0              1
# 6               0            0             1              1              0
# 7               0            0             0              0              0
# 8               0            1             0              1              0
# 9               0            0             0              0              0
# 10              0            0             0              0              0
# 11              0            0             0              6              1
# 12              0            0             0              1              2
# 13              0            0             0              2              0
# 14              0            0             0              0              0
# 15              2           22             7              0              0
# 16              0            1             2             73             41
# 17              0            4             9            111             45
# 18              0            0             0             35             27
# 19              0            0             1              5              6
# 20              0            0             1              6              7
# 21              0            0             2             27              7
# 22              0            0             3             14              0
# 23              0            0             2              3              2
# 24              0            0             0              1              0
# 25              0            0             0              1              0
# 26              0            0             0              1              0
# 27              0            0             0              0              0
# 28              0            0             0              0              0
# 29              0            0             0              2              0
# ...           ...          ...           ...            ...            ...
# 44327           0            0             0              0              1
# 44328           0            0             0              0              0
# 44329           0            0             0              2              0
# 44330           0            0             0              0              0
# 44331           0            0             0              0              0
# 44332           0            0             0              0              0
# 44333           0            0             0              0              0
# 44334           0            0             0              0              0
# 44335           0            0             0              0              0
# 44336           0            0             0              0              9
# 44337           0            0             1              5              8
# 44338           0            0             0              0              0
# 44339           0            0             0              0              0
# 44340           0            0             0              0              0
# 44341           0            0             0              0              2
# 44342           0            0             0              3              0
# 44343           0            0             0              1              0
# 44344           0            0             0              0              0
# 44345           0            0             1              3              6
# 44346           0            0             0              0              0
# 44347           1            5             5             42             19
# 44348           0            4             0              0              0
# 44349           0            0             0             12             16
# 44350           0            1             0              3              4
# 44351           0            1             5             28              5
# 44352           0            0             0              2              1
# 44353           0            1             1             40              5
# 44354           0            0             0              0              0
# 44355          48            7             0              0              0
# 44356          13           15             0              0              0
#
#         ...    at_5000_10000_at at_10000_50000_at at_gt_50000_at  \
# 0       ...                   0                 0              0
# 1       ...                   0                 0              0
# 2       ...              500000                 0              0
# 3       ...                   0                 0              0
# 4       ...                   0                 0              0
# 5       ...                   0                 0              0
# 6       ...                   0                 0              0
# 7       ...                   0           1850000              0
# 8       ...                   0                 0              0
# 9       ...                   0                 0              0
# 10      ...                   0                 0              0
# 11      ...                   0                 0              0
# 12      ...                   0                 0              0
# 13      ...             1500000                 0              0
# 14      ...                   0                 0              0
# 15      ...                   0                 0              0
# 16      ...                   0                 0              0
# 17      ...                   0           1000000              0
# 18      ...                   0                 0              0
# 19      ...                   0                 0              0
# 20      ...                   0                 0              0
# 21      ...             3000000           1000000              0
# 22      ...                   0                 0              0
# 23      ...                   0                 0              0
# 24      ...                   0                 0              0
# 25      ...                   0           1200000              0
# 26      ...                   0                 0              0
# 27      ...                   0                 0              0
# 28      ...              560000           2998000              0
# 29      ...                   0                 0              0
# ...     ...                 ...               ...            ...
# 44327   ...                   0                 0              0
# 44328   ...                   0                 0              0
# 44329   ...                   0           7090700              0
# 44330   ...                   0                 0              0
# 44331   ...                   0                 0              0
# 44332   ...                   0                 0              0
# 44333   ...                   0                 0              0
# 44334   ...                   0                 0              0
# 44335   ...                   0                 0              0
              'at_50_100_cnt','at_100_300_cnt','at_300_500_cnt','at_500_1000_cnt','at_1000_2000_cnt',
              'at_2000_3714_cnt','at_3714_5000_cnt','at_5000_10000_cnt','at_10000_50000_cnt','at_gt_50000_cnt','at_ls_1_at','at_1_5_at',
              'at_5_10_at','at_10_50_at','at_50_100_at','at_100_300_at','at_300_500_at','at_500_1000_at','at_1000_2000_at','at_2000_3714_at',
              'at_3714_5000_at','at_5000_10000_at','at_10000_50000_at','at_gt_50000_at'],axis=1)

# %%
dd = dd.fillna(0)
#dd.to_csv('price.csv',index=0)

# %%
merge = pd.merge(temp,d2,on='mchnt_cd',how='left')
merge = merge.drop(['settle_month'],axis=1)
merge['mean_at']=merge['succ_trans_at'].astype(float)/merge['succ_trans_cnt'].astype(float)
merge['day_mean_at']=merge['succ_trans_at'].astype(float)/merge['day_num'].astype(float)
merge['day_mean_cnt']=merge['succ_trans_cnt'].astype(float)/merge['day_num'].astype(float)
merge
# Out:
#               mchnt_cd succ_trans_cnt succ_trans_at  day_num       mean_at  \
# 0      103210758126025             14        552200     11.0  3.944286e+04
# 1      104211158120061             41       2319200     15.0  5.656585e+04
# 2      105210158120919             11       1478600      6.0  1.344182e+05
# 3      105221000027517              2             0      1.0  0.000000e+00
# 4      105221000033141              2             0      1.0  0.000000e+00
# 5      105226000000935              1         33000      1.0  3.300000e+04
# 6      105228000000874              2         20400      2.0  1.020000e+04
# 7      105228100000444              1       1850000      1.0  1.850000e+06
# 8      105231000000995              3        108000      3.0  3.600000e+04
# 9      105234000001089              1         82500      1.0  8.250000e+04
# 10     105234400000664              1        400000      1.0  4.000000e+05
# 11     105236000001476             13        859800     11.0  6.613846e+04
# 12     113210158120037              4        151000      4.0  3.775000e+04
# 13     113210758120017              8       2032500      6.0  2.540625e+05
# 14     113210958120026              2        150888      2.0  7.544400e+04
# 15     301210158140034             33        119210     17.0  3.612424e+03
# 16     301210758120126            136       4065300     27.0  2.989191e+04
# 17     301999358120070            217       9213400     30.0  4.245806e+04
# 18     301999458121191            100       5547809     30.0  5.547809e+04
# 19     801221058120018             58       8062149     27.0  1.390026e+05
# 20     801221058120351             25       1619700     15.0  6.478800e+04
# 21     801221058120469             43       4909100     21.0  1.141651e+05
# 22     801221058120964             17        261000     12.0  1.535294e+04
# 23     80122105812101A              8        243700      6.0  3.046250e+04
# 24     801221058121242              1         27500      1.0  2.750000e+04
# 25     80122105812369E              3       1513000      3.0  5.043333e+05
# 26     80122105812597B              1         15500      1.0  1.550000e+04
# 27     80122105812641B              1        200000      1.0  2.000000e+05
# 28     80122105812730C              2       3558000      1.0  1.779000e+06
# 29     80122105812775D              3         93900      3.0  3.130000e+04
# ...                ...            ...           ...      ...           ...
# 44327  88722D158129470              2        151000      2.0  7.550000e+04
# 44328  88722D158129632              1        115000      1.0  1.150000e+05
# 44329  88722D158131477             23      10047501     17.0  4.368479e+05
# 44330  88722D158132863              2        426300      2.0  2.131500e+05
# 44331  88722D158133754              3        399800      1.0  1.332667e+05
# 44332  88722D158134645              2             2      1.0  1.000000e+00
# 44333  88722D258120113              3        255200      1.0  8.506667e+04
# 44346  4.316667e+04      1.333333
# 44347  2.154333e+05      4.185185
# 44348  1.600000e+04      4.000000
# 44349  7.052404e+04      1.720000
# 44350  3.912222e+04      1.000000
# 44351  6.102857e+04      1.904762
# 44352  3.050000e+04      1.000000
# 44353  6.316957e+04      2.173913
# 44354  1.000000e+00      1.000000
# 44355  2.366393e+03      4.607143
# 44356  1.990500e+03      2.071429
#
# [44357 rows x 7 columns]

# %%
high = dd[dd['high_cnt']>2*(dd['mid_cnt']+dd['low_cnt'])]
mid = dd[dd['mid_cnt']>2*(dd['high_cnt']+dd['low_cnt'])]
low = dd[dd['low_cnt']>2*(dd['high_cnt']+dd['mid_cnt'])]
#temp =temp[temp['high_cnt']<10]
#temp =temp[temp['high_cnt']>temp['low_cnt']]
print(len(high),len(mid),len(low))
#low[low['mean_at']!=0].sort(columns=['mean_at'],axis=0,ascending=False)
#high
# Out:
# 3511 26044 3473

# %%
ddd = dd[dd['high_cnt']<=2*(dd['mid_cnt']+dd['low_cnt'])]
ddd = ddd[ddd['mid_cnt']<=2*(ddd['high_cnt']+ddd['low_cnt'])]
ddd = ddd[ddd['low_cnt']<=2*(ddd['high_cnt']+ddd['mid_cnt'])]
len(ddd)
# Out:
# 9093

# %%
dd = dd[dd['mean_at']>=10]
len(dd)
# Out:
# 42121

# %%
status(ddd['mean_at'])
# Out:
# 总数        9.093000e+03
# 最小值       2.375250e+03
# 最小值位置     1.441600e+04
# 25%分位数    9.083272e+04
# 中位数       3.455708e+05
# 75%分位数    5.083333e+05
# 90%       7.459474e+05
# 95%       9.679333e+05
# 均值        3.760274e+05
# 最大值       5.403600e+06
# 最大值位数     1.392300e+04
# 平均绝对偏差    2.385864e+05
# 方差        1.232222e+11
# 标准差       3.510302e+05
# 偏度        2.809322e+00
# 峰度        1.985780e+01
# dtype: float64

# %%
import math
def score(x1,x2,mean):
    return int(80*len(d1[d1['card_num'].astype(float)<=x1])/57416+0.5*x2*math.log(x1/mean,math.e))
score(10,2.3,50)
# Out:
# 48

# %%
ss = [score(d1.iloc[i,2],d1.iloc[i,3],51) for i in range(len(d1))]
d1['score'] = ss
d1
# Out:
#        settle_month         mchnt_cd  card_num  per_card_trans_cnt  score
# 0            201804  100210654110004       6.0            1.166667     41
# 1            201804  100210654110005      32.0            1.593750     63
# 2            201804  100210654110189       1.0            1.000000     16
# 3            201804  100210658120089       2.0            1.000000     26
# 4            201804  100210758120033      23.0            1.304348     59
# 5            201804  100210758120049       3.0            1.000000     32
# 6            201804  100210758120168      21.0            1.047619     58
# 7            201804  100210958120188      23.0            2.869565     58
# 8            201804  100210958120193      17.0            1.529412     55
# 9            201804  100211254110053     171.0            1.467836     78
# 10           201804  100211258120336       8.0            1.000000     45
# 11           201804  100211358120066       7.0            1.142857     43
# 12           201804  100211358120534       8.0            1.125000     45
# 13           201804  100211358120535       9.0            1.222222     47
# 14           201804  100211358120552       2.0            1.000000     26
# 15           201804  100211358120609       9.0            1.000000     47
# 16           201804  100211358120654     127.0            1.141732     76
# 17           201804  100211458120261      40.0            1.150000     66
# 18           201804  100310054110019   14185.0            1.649630     84
# 19           201804  100310054110025    8780.0            1.621526     84
# 20           201804  100310054110026    9263.0            1.715103     84
# 21           201804  100310054110030    7286.0            1.702855     84
# 22           201804  100310054110031    6216.0            1.674871     83
# 23           201804  100310054110033   11553.0            1.566952     84
# 24           201804  100310054110036      74.0            1.081081     72
# 25           201804  100310054110037    5275.0            1.478104     83
# 26           201804  100310054110038    9696.0            1.614480     84
# 27           201804  100310054110039   13188.0            1.661131     84
# 28           201804  100310054110098    7149.0            1.602602     83
# 29           201804  100310054110104   10313.0            1.506254     83
# ...             ...              ...       ...                 ...    ...
# 57386        201804  QRC490022005496      91.0            1.560440     74
# 57387        201804  QRC490022005497      37.0            1.405405     65
# 57388        201804  QRC490022005499     189.0            2.164021     78
# 57389        201804  QRC490022005502      43.0            1.186047     67
# 57390        201804  QRC490022005515     385.0            2.410390     81
# 57391        201804  QRC490022005516      18.0            1.388889     56
# 57392        201804  QRC490022005528     169.0            1.775148     78
# 57393        201804  QRC490022005541     128.0            7.960938     79
# 57394        201804  QRC490022005559       2.0            2.000000     25
# 57395        201804  QRC490022005630     148.0            2.675676     78
# 57396        201804  QRC490022005639      33.0            1.878788     64
# 57397        201804  QRC490022005673      23.0            1.130435     59
# 57398        201804  QRC490022005678      28.0            4.750000     60
# 57399        201804  QRC490022005688     334.0            2.455090     80
# 57400        201804  QRC490022005740      50.0            1.240000     69
# 57401        201804  QRC490022005742       6.0            1.166667     41
# 57402        201804  QRC490022005766     128.0            8.742188     80
# 57403        201804  QRC490022005821      82.0            2.451220     73
# 57404        201804  QRC490022005824     179.0            1.625698     78
# 57405        201804  QRC490022005835      25.0            1.240000     60
# 57406        201804  QRC490022005866       1.0            1.000000     16
# 57407        201804  QRC490022005868     133.0            1.902256     77
# 57408        201804  QRC490022005869      68.0            2.323529     72
# 57409        201804  QRC490022005902     395.0            2.602532     81
# 57410        201804  QRC490022005907      44.0            1.250000     67
# 57411        201804  QRC490022005912     132.0            4.174242     78
# 57412        201804  QRC490022005933       2.0            5.500000     19
# 57413        201804  QRC490022005947       8.0            2.250000     44
# 57414        201804  QRC490022005961     650.0            3.336923     83
# 57415        201804  QRC490022005967      12.0            1.833333     50
#
# [57416 rows x 5 columns]

# %%
import pandas as pd
d2 = pd.read_csv('mean.csv')
#d2 = pd.read_table('mchnt_days.DEL')
d2.head()
# Out:
#           mchnt_cd  succ_trans_cnt  succ_trans_at  day_num        mean_at  \
# 0  103210758126025              14         552200     11.0   39442.857143
# 1  104211158120061              41        2319200     15.0   56565.853659
# 2  105210158120919              11        1478600      6.0  134418.181818
# 3  105221000027517               2              0      1.0       0.000000
# 4  105221000033141               2              0      1.0       0.000000
#
#      day_mean_at  day_mean_cnt
# 0   50200.000000      1.272727
# 1  154613.333333      2.733333
# 2  246433.333333      1.833333
# 3       0.000000      2.000000
# 4       0.000000      2.000000

# %%
xx = d2[['day_mean_at','day_mean_cnt']]
xx = xx.fillna(0)
xx['score'] = xx['day_mean_at'] * xx['day_mean_cnt']
#xx = xx[xx['day_mean_cnt']>5]
xx.head()
# Out:
#      day_mean_at  day_mean_cnt          score
# 0   50200.000000      1.272727   63890.909091
# 1  154613.333333      2.733333  422609.777778
# 2  246433.333333      1.833333  451794.444444
# 3       0.000000      2.000000       0.000000
# 4       0.000000      2.000000       0.000000

# %%
score = score[score['score']>0]
score = score[score['score']<90]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
#fig, axes = plt.subplots(2,2,figsize=(12, 10)) 
#sns.kdeplot(d1['score'], shade=True)
sns.distplot(score['score'],bins=50)

# %%
d1.to_csv('score_new.csv',index=0)

# %%
def statistic_plot(x) : 
    xx = [x.quantile(float(i/100)) for i in range(0,100,5)]
    yy = [i for i in range(0,100,5)]
    #print(xx,yy)
    plt.figure()
    plt.plot(yy,xx,color="red",linewidth=2)
    plt.xlabel("rate%") #X轴标签
    plt.ylabel("days_num") #Y轴标签
        
    return pd.Series([x.count(),x.min(),x.idxmin(),x.quantile(.25),x.median(),
                      x.quantile(.75),x.quantile(.9),x.quantile(.95),x.mean(),x.max(),x.idxmax(),x.mad(),x.var(),
                      x.std(),x.skew(),x.kurt()],index=['总数','最小值','最小值位置','25%分位数',
                    '中位数','75%分位数','90%','95%','均值','最大值','最大值位数','平均绝对偏差','方差','标准差','偏度','峰度'])

# %%
#feature_v1.extend(feature_v2)
print(feature_v2)
df = df.fillna(0)
dd = df[feature_v2]
# Out:
# ['settle_cnt', 'settle_at', 'mchnt_cd', 'at_ls_1_cnt', 'at_1_5_cnt', 'at_5_10_cnt', 'at_10_50_cnt', 'at_50_100_cnt', 'at_100_300_cnt', 'at_300_500_cnt', 'at_500_1000_cnt', 'at_1000_2000_cnt', 'at_2000_3714_cnt', 'at_3714_5000_cnt', 'at_5000_10000_cnt', 'at_10000_50000_cnt', 'at_gt_50000_cnt', 'at_ls_1_at', 'at_1_5_at', 'at_5_10_at', 'at_10_50_at', 'at_50_100_at', 'at_100_300_at', 'at_300_500_at', 'at_500_1000_at', 'at_1000_2000_at', 'at_2000_3714_at', 'at_3714_5000_at', 'at_5000_10000_at', 'at_10000_50000_at', 'at_gt_50000_at']

# %%
dd[dd['at_100_300_cnt'].astype(float)>1600]
# Out:
#       at_ls_1_cnt at_1_5_cnt at_5_10_cnt at_10_50_cnt at_50_100_cnt  \
# 7056            0          0           0            2            67
# 20322          12          1           5          109           364
#
#       at_100_300_cnt at_300_500_cnt at_500_1000_cnt at_1000_2000_cnt  \
# 7056            1753            543             146               16
# 20322           1675            231              59                4
#
#       at_2000_3714_cnt      ...       at_50_100_at at_100_300_at  \
# 7056                 4      ...             543500      34349300
# 20322                6      ...            2796000      29290128
#
#       at_300_500_at at_500_1000_at at_1000_2000_at at_2000_3714_at  \
# 7056       20270200        9979000         2176100         1070700
# 20322       8608100        3786100          551000         1553900
#
#       at_3714_5000_at at_5000_10000_at at_10000_50000_at at_gt_50000_at
# 7056                0           597600                 0              0
# 20322         1842900          1373300           1300000              0
#
# [2 rows x 28 columns]

# %%
def status(x) : 
    return pd.Series([x.count(),x.min(),x.idxmin(),x.quantile(.25),x.median(),
                      x.quantile(.75),x.quantile(.9),x.quantile(.95),x.mean(),x.max(),x.idxmax(),x.mad(),x.var(),
                      x.std(),x.skew(),x.kurt()],index=['总数','最小值','最小值位置','25%分位数',
                    '中位数','75%分位数','90%','95%','均值','最大值','最大值位数','平均绝对偏差','方差','标准差','偏度','峰度'])

# %%
status(xx['credit_card_at'].astype(float))
# Out:
# 总数        4.113500e+04
# 最小值       0.000000e+00
# 最小值位置     5.000000e+00
# 25%分位数    8.260000e+04
# 中位数       7.011000e+05
# 75%分位数    3.403532e+06
# 90%       1.149258e+07
# 95%       1.999115e+07
# 均值        4.957716e+06
# 最大值       5.537442e+08
# 最大值位数     4.359600e+04
# 平均绝对偏差    6.502312e+06
# 方差        3.217077e+14
# 标准差       1.793621e+07
# 偏度        1.360022e+01
# 峰度        2.768590e+02
# dtype: float64

# %%
status(dd['total_disc_at'].astype(float))
# Out:
# 总数        4.435700e+04
# 最小值       0.000000e+00
# 最小值位置     3.000000e+00
# 25%分位数    3.260000e+02
# 中位数       3.132000e+03
# 75%分位数    1.493900e+04
# 90%       4.707120e+04
# 95%       8.299640e+04
# 均值        2.044930e+04
# 最大值       6.473397e+06
# 最大值位数     2.974200e+04
# 平均绝对偏差    2.640162e+04
# 方差        5.769737e+09
# 标准差       7.595879e+04
# 偏度        2.369836e+01
# 峰度        1.352038e+03
# dtype: float64

# %%
dd['mean_cnt'] = dd['succ_trans_at'].astype(float)/dd['succ_trans_cnt'].astype(float)
dd.head()
# Out:
# E:\Anaconda\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#   succ_trans_cnt succ_trans_at max_succ_trans_at credit_card_cnt  \
# 0             14        552200            194800              12
# 1             41       2319200            361000              31
# 2             11       1478600            500000               5
# 3              2             0               100               0
# 4              2             0               100               0
#
#   credit_card_at total_disc_at ext_cups_disc_at term_num       mean_cnt
# 0         511600          2290              338        1   39442.857143
# 1        2490300          5768              790        1   56565.853659
# 2        1241900          6417              962        1  134418.181818
# 3              0             0                0        1       0.000000
# 4              0             0                0        1       0.000000

# %%
###数据筛选，去除离群值点,xx
xx = dd[dd['mean_cnt']>0]
xx = xx[xx['mean_cnt'].astype(float)<1000000]
xx = xx[xx['succ_trans_cnt'].astype(float)<5000]
#xx = xx[xx['succ_trans_cnt']<5000]
xx = xx[xx['succ_trans_at'].astype(float)<500000000]
#xx = xx.drop(['term_num'],axis=1)
xx = xx[xx['total_disc_at'].astype(float)<1000000]
xx
# Out:
#       succ_trans_cnt succ_trans_at max_succ_trans_at total_disc_at  \
# 0                 14        552200            194800          2290
# 1                 41       2319200            361000          5768
# 2                 11       1478600            500000          6417
# 5                  1         33000             33000           116
# 6                  2         20400             10700            36
# 8                  3        108000             93000           487
# 9                  1         82500             82500           371
# 10                 1        400000            400000          1800
# 11                13        859800            200000          3870
# 12                 4        151000             50000           680
# 13                 8       2032500            500000          9093
# 14                 2        150888             88888           590
# 15                33        119210              9000           716
# 16               136       4065300            157700         17620
# 17               217       9213400           1000000         39780
# 18               100       5547809            250800         23297
# 19                58       8062149            797200         36183
# 20                25       1619700            378500          7202
# 21                43       4909100           1000000         21894
# 22                17        261000             29800           852
# 23                 8        243700            100000          1023
# 24                 1         27500             27500           124
# 25                 3       1513000           1200000          6773
# 26                 1         15500             15500            70
# 27                 1        200000            200000           900
# 29                 3         93900             65000           423
# 30                14        409100             55000          1634
# 31                21       2947680            543200         13266
# 32                10        291700            100000          1112
# 33                 4        364400            200000          1608
# ...              ...           ...               ...           ...
# 44327              2        151000            107000           680
# 44328              1        115000            115000           518
# 44329             23      10047501           2999600         45215
# 44330              2        426300            329500          1919
# 44331              3        399800            153800          1799
# 44332              2             2                 1             0
# 44333              3        255200            115200          1148
# 44334              5       1295700            294200          5831
# 44335              4        901000            376200          4055
# 44336             53       7694500            599800         35258
# 44337            216     147173450           9512000        660628
# 44338              1        998000            998000          4491
# 44339              5        532400            234600          2397
# 44340              6        992657            199400          4327
# 44341              4        632800            425000          2848
# 44342              3         48500             16900            87
# 44343              1         27900             27900            50
# 44344              7       2368902           1054700         13029
# 44345             17        632601            100000          3797
# 44346              4        129500             73000           777
# 44347            113       5816700            500000         34152
# 44348              4         16000              8000            28
# 44349             43       1763101             96800         10578
# 44350              9        352100            125000          2111
# 44351             40       1281600            617000          7690
# 44352              3         91500             44000           412
# 44353             50       1452900            135800          5880
# 44354              1             1                 1             0
# 44355            129         66259              2726           488
# 44356             29         27867              3349           190
#
#             mean_cnt
# 0       39442.857143
# 1       56565.853659
# 2      134418.181818
# 5       33000.000000
# 6       10200.000000
# 8       36000.000000
# 9       82500.000000
# 10     400000.000000
# 11      66138.461538
# 12      37750.000000
# 13     254062.500000
# 14      75444.000000
# 15       3612.424242
# 16      29891.911765
# 17      42458.064516
# 18      55478.090000
# 19     139002.568966
# 20      64788.000000
# 21     114165.116279
# 22      15352.941176
# 23      30462.500000
# 24      27500.000000
# 25     504333.333333
# 26      15500.000000
# 27     200000.000000
# 29      31300.000000
# 30      29221.428571
# 31     140365.714286
# 32      29170.000000
# 33      91100.000000
# ...              ...
# 44327   75500.000000
# 44328  115000.000000
# 44329  436847.869565
# 44330  213150.000000
# 44331  133266.666667
# 44332       1.000000
# 44333   85066.666667
# 44334  259140.000000
# 44335  225250.000000
# 44336  145179.245283
# 44337  681358.564815
# 44338  998000.000000
# 44339  106480.000000
# 44340  165442.833333
# 44341  158200.000000
# 44342   16166.666667
# 44343   27900.000000
# 44344  338414.571429
# 44345   37211.823529
# 44346   32375.000000
# 44347   51475.221239
# 44348    4000.000000
# 44349   41002.348837
# 44350   39122.222222
# 44351   32040.000000
# 44352   30500.000000
# 44353   29058.000000
# 44354       1.000000
# 44355     513.635659
# 44356     960.931034
#
# [41102 rows x 5 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

X = np.array(dd)
X_scaled = preprocessing.scale(X)
print(X_scaled.mean(axis=0))

cluster_num=4
clf = KMeans(n_clusters=cluster_num)
km = clf.fit(X_scaled)

#3个中心
print(clf.cluster_centers_)

#每个样本所属的簇
print(clf.labels_)

#用来评估簇的个数是否合适，距离越小说明簇分的越好，选取临界点的簇个数
print(clf.inertia_)
# Out:
# E:\Anaconda\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

X = np.array(xx)
X_scaled = preprocessing.scale(X)
print(X_scaled.mean(axis=0))

cluster_num=3
clf = KMeans(n_clusters=cluster_num)
km2 = clf.fit(X_scaled)

#3个中心
print(clf.cluster_centers_)

#每个样本所属的簇
print(clf.labels_)

#用来评估簇的个数是否合适，距离越小说明簇分的越好，选取临界点的簇个数
print(clf.inertia_)
# Out:
# [ 5.91867623e-17 -3.10070777e-17]
# [[ 2.76215689  0.33322999]
#  [-0.1892767  -0.05805382]
#  [-0.40358692 23.21009925]]
# [1 1 1 ... 0 1 0]
# 2487.1116265708106

# %%
## 未对离群值点处理
# %matplotlib inline
print(clf.predict(dd))


##聚类结果可视化
plt.plot(range(0,clf.labels_.size),clf.labels_.tolist(),'bx')
plt.title("cluster result")
# Out:
# [3 3 3 ... 0 2 2]

# %%
## 对离群值点处理过后
# %matplotlib inline
print(clf.predict(xx))


##聚类结果可视化
plt.plot(range(0,clf.labels_.size),clf.labels_.tolist(),'bx')
plt.title("cluster result")
# Out:
# [0 0 0 ... 0 0 0]

# %%
#聚类中心可视化
cluster_num=len(clf.cluster_centers_)
#column_nm=["trans_cnt","succ_trans_cnt","succ_trans_at","settle_cnt","neg_settle_cnt","settle_at","consume_cnt","neg_consume_cnt","consume_at","succ_settle_cnt","succ_settle_at","common_ds_cnt","common_ds_at","max_succ_trans_at","credit_card_cnt","neg_credit_card_cnt","debit_card_cnt","neg_debit_card_cnt","credit_card_at","debit_card_at","credit_fail_cnt","credit_fail_overdrawn_cnt","credit_fail_pin_cnt","credit_fail_insufficient_cnt","credit_fail_expiration_cnt","credit_fail_id_mismatch_cnt","debit_fail_cnt","debit_fail_overdrawn_cnt","debit_fail_pin_cnt","debit_fail_insufficient_cnt","debit_fail_expiration_cnt","debit_fail_id_mismatch_cnt","cross_consume_cnt","cross_consume_at","retrieval_cnt","retrieval_at","revoke_cnt","revoke_at","tr_return_cnt","tr_return_at","total_disc_at","ext_cups_disc_at","ext_iss_disc_at","acq_disc_at","brand_disc_at","mchnt_disc_at","iss_swt_disc_at","acq_swt_disc_at","iss_brand_disc_at","acq_brand_disc_at","iss_exch_disc_at","acq_exch_disc_at","cross_disc_at","hce_prod_cnt","hce_prod_at","am_prod_cnt","am_prod_at","paymst_prod_cnt","paymst_prod_at","payic_prod_cnt","payic_prod_at","bigmchnt_prod_cnt","bigmchnt_prod_at","huawei_prod_cnt","huawei_prod_at","mi_prod_cnt","mi_prod_at","other_qp_prod_cnt","other_qp_prod_at","nopwd_petty_cnt","nopwd_petty_at","web_cnt","web_at","mobile_cnt","mobile_at","atm_cnt","atm_at","pos_cnt","pos_at","tel_cnt","tel_at","peasant_cnt","peasant_at","other_chnl_at","other_chnl_cnt","at_ls_1_cnt","at_1_5_cnt","at_5_10_cnt","at_10_50_cnt","at_50_100_cnt","at_100_300_cnt","at_300_500_cnt","at_500_1000_cnt","at_1000_2000_cnt","at_2000_3714_cnt","at_3714_5000_cnt","at_5000_10000_cnt","at_10000_50000_cnt","at_gt_50000_cnt","at_ls_1_at","at_1_5_at","at_5_10_at","at_10_50_at","at_50_100_at","at_100_300_at","at_300_500_at","at_500_1000_at","at_1000_2000_at","at_2000_3714_at","at_3714_5000_at","at_5000_10000_at","at_10000_50000_at","at_gt_50000_at","term_num","is_white_list_mchnt"]
plt.figure(figsize=(20,5))
for i in range(cluster_num):
    plt.subplot(1,cluster_num,i+1)
    rects = plt.bar(left=0,bottom=range(len(clf.cluster_centers_[i])),width=clf.cluster_centers_[i],height=0.6,color='g',orientation = "horizontal" )
    if i==0:
        plt.yticks(range(len(feature_v2)),feature_v2,rotation=0)
        plt.title("cluster-center")

# %%
#聚类中心可视化
cluster_num=len(clf.cluster_centers_)
#column_nm=["trans_cnt","succ_trans_cnt","succ_trans_at","settle_cnt","neg_settle_cnt","settle_at","consume_cnt","neg_consume_cnt","consume_at","succ_settle_cnt","succ_settle_at","common_ds_cnt","common_ds_at","max_succ_trans_at","credit_card_cnt","neg_credit_card_cnt","debit_card_cnt","neg_debit_card_cnt","credit_card_at","debit_card_at","credit_fail_cnt","credit_fail_overdrawn_cnt","credit_fail_pin_cnt","credit_fail_insufficient_cnt","credit_fail_expiration_cnt","credit_fail_id_mismatch_cnt","debit_fail_cnt","debit_fail_overdrawn_cnt","debit_fail_pin_cnt","debit_fail_insufficient_cnt","debit_fail_expiration_cnt","debit_fail_id_mismatch_cnt","cross_consume_cnt","cross_consume_at","retrieval_cnt","retrieval_at","revoke_cnt","revoke_at","tr_return_cnt","tr_return_at","total_disc_at","ext_cups_disc_at","ext_iss_disc_at","acq_disc_at","brand_disc_at","mchnt_disc_at","iss_swt_disc_at","acq_swt_disc_at","iss_brand_disc_at","acq_brand_disc_at","iss_exch_disc_at","acq_exch_disc_at","cross_disc_at","hce_prod_cnt","hce_prod_at","am_prod_cnt","am_prod_at","paymst_prod_cnt","paymst_prod_at","payic_prod_cnt","payic_prod_at","bigmchnt_prod_cnt","bigmchnt_prod_at","huawei_prod_cnt","huawei_prod_at","mi_prod_cnt","mi_prod_at","other_qp_prod_cnt","other_qp_prod_at","nopwd_petty_cnt","nopwd_petty_at","web_cnt","web_at","mobile_cnt","mobile_at","atm_cnt","atm_at","pos_cnt","pos_at","tel_cnt","tel_at","peasant_cnt","peasant_at","other_chnl_at","other_chnl_cnt","at_ls_1_cnt","at_1_5_cnt","at_5_10_cnt","at_10_50_cnt","at_50_100_cnt","at_100_300_cnt","at_300_500_cnt","at_500_1000_cnt","at_1000_2000_cnt","at_2000_3714_cnt","at_3714_5000_cnt","at_5000_10000_cnt","at_10000_50000_cnt","at_gt_50000_cnt","at_ls_1_at","at_1_5_at","at_5_10_at","at_10_50_at","at_50_100_at","at_100_300_at","at_300_500_at","at_500_1000_at","at_1000_2000_at","at_2000_3714_at","at_3714_5000_at","at_5000_10000_at","at_10000_50000_at","at_gt_50000_at","term_num","is_white_list_mchnt"]
plt.figure(figsize=(20,5))
for i in range(cluster_num):
    plt.subplot(1,cluster_num,i+1)
    rects = plt.bar(left=0,bottom=range(len(clf.cluster_centers_[i])),width=clf.cluster_centers_[i],height=0.6,color='g',orientation = "horizontal" )
    if i==0:
        plt.yticks(range(len(['day_mean_at','day_mean_cnt'])),['day_mean_at','day_mean_cnt'],rotation=0)
        plt.title("cluster-center")

# %%
#主成分分析
pca=PCA(n_components=2)
# cluster_nums=5
# clt = KMeans(n_clusters=cluster_nums)

matrix=pd.DataFrame()
matrix['cluster'] = km.predict(X_scaled)
matrix['x'] = pca.fit_transform(X_scaled)[:,0]
matrix['y'] = pca.fit_transform(X_scaled)[:,1]
#matrix['z'] = pca.fit_transform(X_scaled)[:,2]
#matrix = matrix.reset_index()
 
#customer_clusters = matrix[['cluster', 'x', 'y']]
matrix.head()
# Out:
#    cluster         x         y
# 0        0  0.695632  0.091392
# 1        0  0.319362  0.446660
# 2        0  0.568842 -0.237939
# 3        0  0.979585 -0.220903
# 4        0  0.979585 -0.220903

# %%
matrix['cluster'].value_counts()
# Out:
# 0    43070
# 1     1021
# 3      262
# 2        1
# Name: cluster, dtype: int64

# %%
matrix['cluster'].value_counts()
# Out:
# 0    37060
# 2     3876
# 1      166
# Name: cluster, dtype: int64

# %%
from ggplot import *
 
ggplot(matrix, aes(x='x', y='y' ,color='cluster')) + geom_point(size=75) + ggtitle("Customers Grouped by Cluster")
# Out:
# <ggplot: (39660913)>

# %%
from ggplot import *
 
ggplot(matrix, aes(x='x', y='y' ,color='cluster')) + geom_point(size=75) + ggtitle("Customers Grouped by Cluster")
# Out:
# <ggplot: (-9223372036819812306)>

# %%
##查看每个类别的商户名称
sample_num = clf.labels_.size
label_list=[[] for row in range(cluster_num)]
for j in range(sample_num):
    mchnt_nm = data[j][124]
    label_list[clf.labels_[j]].append(mchnt_nm)

##一类是交易量少的,一类交易量大的，另一类小额高频

#写文件
fw = open("canyin_label_32.txt","w",encoding="utf8")
for idx in range(len(label_list)):
    for mchnt_nm in label_list[idx]:
        fw.write("%d\t%s\n" % (idx,mchnt_nm))
fw.close()

# %%
temp = pd.read_table('./mchnt/liaoning_canyin.DEL')
temp = temp[['a.mchnt_cd','a.first_mchnt_cn_abbr']]
temp
# Out:
# E:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#             a.mchnt_cd a.first_mchnt_cn_abbr
# 0      103210758126025           北镇市个体湾月亮鸽子馆
# 1      104211158120061           盘锦港丰大酒店有限公司
# 2      105210158120919     沈阳沈铁房地产开发集团玖鼎汇餐饮管
# 3      105221000027517          沈阳市于洪区油边心管饭店
# 4      105221000033141          沈阳市和平区乐福家火锅店
# 5      105226000000935          丹东边境合作区祥祥涮烤店
# 6      105228000000874      营口市鲅鱼圈区熊岳镇老师傅烤肉店
# 7      105228100000444          大石桥市大脸猫私厨美食店
# 8      105231000000995        辽阳市白塔区周记馅饼家常菜馆
# 9      105234000001089     朝阳市双塔区凌河街喜多多海鲜饺子城
# 10     105234400000664         喀左县大城子镇企顺家常菜馆
# 11     105236000001476          葫芦岛市龙港区老锦西饭店
# 12     113210158120037         康平县康平镇含光街个体巴图
# 13     113210758120017          锦州市太和区个体顺峰餐厅
# 14     113210958120026         阜新蒙古族自治县旧庙镇朝辉
# 15     301210158140034           沈阳市和平区都市友餐厅
# 16     301210758120126           凌河区名都晓荷塘火锅店
# 17     301999358120070                  白玉串城
